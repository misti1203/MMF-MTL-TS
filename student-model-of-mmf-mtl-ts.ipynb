# %% [markdown]
# # 1. Import needed libraries

# %%
import os
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
#---------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
#---------------------------------------
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#---------------------------------------
import warnings
warnings.filterwarnings("ignore")
# Out:
# 2024-03-13 13:32:55.325328: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-13 13:32:55.325424: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-13 13:32:55.463527: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # 2. Preprocessing

# %% [markdown]
# ## 2.1 Load data

# %%
'''class_dict = tr_gen.class_indices
classes = list(class_dict.keys())
images, labels = next(ts_gen)

plt.figure(figsize=(20, 20))

for i, (image, label) in enumerate(zip(images, labels)):
    plt.subplot(4,4, i + 1)
    plt.imshow(image)
    class_name = classes[np.argmax(label)]
    plt.title(class_name, color='k', fontsize=15)

plt.show()'''
# Out:
# "class_dict = tr_gen.class_indices\nclasses = list(class_dict.keys())\nimages, labels = next(ts_gen)\n\nplt.figure(figsize=(20, 20))\n\nfor i, (image, label) in enumerate(zip(images, labels)):\n    plt.subplot(4,4, i + 1)\n    plt.imshow(image)\n    class_name = classes[np.argmax(label)]\n    plt.title(class_name, color='k', fontsize=15)\n\nplt.show()"

# %% [markdown]
# # 3. Building Deep Learning Model

# %%
img_rows, img_cols = 128, 128
input_shape = (img_rows, img_cols, 3)

#n_classes = df['category'].nunique()
n_classes = 4
print('Total number of unique categories:', n_classes)

from os import listdir, makedirs
from os.path import isfile, join, basename, splitext, isfile, exists

import numpy as np
import pandas as pd

from tqdm import tqdm_notebook

import tensorflow as tf
import keras.backend as K

import keras
from keras.models import Sequential, Model
from keras.layers import Dropout, Dense, Flatten, BatchNormalization
from keras.layers import DepthwiseConv2D, SeparableConvolution2D, Convolution2D, Conv2D,GRU, LSTM, AlphaDropout, Embedding, ZeroPadding2D,AveragePooling2D, MaxPooling2D, GlobalAveragePooling2D, GlobalMaxPooling2D, Dropout
from keras.layers import Concatenate, Average, Maximum, Bidirectional, TimeDistributed
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
#from keras.engine.input_layer import Input
from keras.models import load_model
#from keras.initializers import LecunNormal

import matplotlib.pyplot as plt
import seaborn as sns

#pd.set_option('precision', 30)
np.set_printoptions(precision = 30)


#tf.set_random_seed(1090)

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as img

import cv2
import itertools
import pathlib
import warnings
from PIL import Image
from random import randint
warnings.filterwarnings('ignore')

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import balanced_accuracy_score as BAS
from sklearn.metrics import classification_report, confusion_matrix


from tensorflow import keras
from keras import layers
import tensorflow as tf
#import tensorflow_addons as tfa
from tensorflow.keras.preprocessing import image_dataset_from_directory
##from keras.utils.vis_utils import plot_model
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, GlobalAveragePooling2D

from distutils.dir_util import copy_tree, remove_tree

import os
#print(os.listdir("../input/alzheimer-mri-dataset/Dataset"))
import tensorflow as tf
from keras.datasets import mnist
import cv2
import os
import pathlib
from keras.layers import Conv2D, Conv2DTranspose,Concatenate, Dropout, Dense, Reshape, LayerNormalization, LeakyReLU
from keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import f1_score, recall_score, precision_score
print("TensorFlow Version:", tf.__version__)
# Out:
# Total number of unique categories: 4
# TensorFlow Version: 2.15.0

# %%
## for covid disease datasets: ctscan and cxr
import numpy as np
X_test_covid_ct = np.load('/kaggle/input/for-teacher-2-covid-ct-scan-and-cxr-data/X_test_covid_ct.npy')
X_test_covid_ct = X_test_covid_ct.astype(np.float32)

X_test_covid_cxr = np.load('/kaggle/input/for-teacher-2-covid-ct-scan-and-cxr-data/X_test_covid_cxr.npy')
X_test_covid_cxr = X_test_covid_cxr.astype(np.float32)

X_val_covid_ct = np.load('/kaggle/input/for-teacher-2-covid-ct-scan-and-cxr-data/X_val_covid_ct.npy')
X_val_covid_ct = X_val_covid_ct.astype(np.float32)

X_val_covid_cxr = np.load('/kaggle/input/for-teacher-2-covid-ct-scan-and-cxr-data/X_val_covid_cxr.npy')
X_val_covid_cxr = X_val_covid_cxr.astype(np.float32)

images_train_covid_ct = np.load('/kaggle/input/for-teacher-2-covid-ct-scan-and-cxr-data/images_train_covid_ct.npy')
images_train_covid_ct = images_train_covid_ct.astype(np.float32)

images_train_covid_cxr = np.load('/kaggle/input/for-teacher-2-covid-ct-scan-and-cxr-data/images_train_covid_cxr.npy')
images_train_covid_cxr = images_train_covid_cxr.astype(np.float32)

labels_train_covid_ct = np.load('/kaggle/input/for-teacher-2-covid-ct-scan-and-cxr-data/labels_train_covid_ct.npy')
labels_train_covid_cxr = np.load('/kaggle/input/for-teacher-2-covid-ct-scan-and-cxr-data/labels_train_covid_cxr.npy')

y_test_covid_ct = np.load('/kaggle/input/for-teacher-2-covid-ct-scan-and-cxr-data/y_test_covid_ct.npy')
y_test_covid_cxr = np.load('/kaggle/input/for-teacher-2-covid-ct-scan-and-cxr-data/y_test_covid_cxr.npy')
y_val_covid_ct = np.load('/kaggle/input/for-teacher-2-covid-ct-scan-and-cxr-data/y_val_covid_ct.npy')
y_val_covid_cxr = np.load('/kaggle/input/for-teacher-2-covid-ct-scan-and-cxr-data/y_val_covid_cxr.npy')


print('X_test_covid_ct:',X_test_covid_ct.shape)
print('X_test_covid_cxr:',X_test_covid_cxr.shape)
print('X_val_covid_ct:',X_val_covid_ct.shape)
print('X_val_covid_cxr:',X_val_covid_cxr.shape)

print('images_train_covid_ct:',images_train_covid_ct.shape)
print('images_train_covid_cxr:',images_train_covid_cxr.shape)
print('labels_train_covid_ct:',labels_train_covid_ct.shape)
print('labels_train_covid_cxr:',labels_train_covid_cxr.shape)

print('y_test_covid_ct:',y_test_covid_ct.shape)
print('y_test_covid_cxr:',y_test_covid_cxr.shape)
print('y_val_covid_ct:',y_val_covid_ct.shape)
print('y_val_covid_cxr:',y_val_covid_cxr.shape)
# Out:
# X_test_covid_ct: (656, 128, 128, 3)
# X_test_covid_cxr: (656, 128, 128, 3)
# X_val_covid_ct: (655, 128, 128, 3)
# X_val_covid_cxr: (655, 128, 128, 3)
# images_train_covid_ct: (5712, 128, 128, 3)
# images_train_covid_cxr: (5712, 128, 128, 3)
# labels_train_covid_ct: (5712, 2)
# labels_train_covid_cxr: (5712, 3)
# y_test_covid_ct: (656, 2)
# y_test_covid_cxr: (656, 3)
# y_val_covid_ct: (655, 2)
# y_val_covid_cxr: (655, 3)

# %% [markdown]
# ### Generated soft probabilities by teacher 2 model of MMF-MTL-TS approach

# %%
soft_prob_covid_cxr = np.load('/kaggle/input/teacher-2-soft-predictions/soft_pred_train_covid_cxr.npy')
soft_prob_covid_ct = np.load('/kaggle/input/teacher-2-soft-predictions/y_pred_covid_ctscan.npy')

print('soft_prob_covid_cxr:',soft_prob_covid_cxr.shape)
print('soft_prob_covid_ct:',soft_prob_covid_ct.shape)
# Out:
# soft_prob_covid_cxr: (5712, 3)
# soft_prob_covid_ct: (5712, 2)

# %%
## for brain disease datasets: mri and ctscan
import numpy as np
X_test_brain_mri = np.load('/kaggle/input/teacher-1-brain-mri-ctscan/X_test_mri.npy')
X_test_brain_mri = X_test_brain_mri.astype(np.float32)

X_test_brain_ct = np.load('/kaggle/input/teacher-1-brain-mri-ctscan/X_test_ct.npy')
X_test_brain_ct = X_test_brain_ct.astype(np.float32)

X_val_brain_mri = np.load('/kaggle/input/teacher-1-brain-mri-ctscan/X_val_mri.npy')
X_val_brain_mri = X_val_brain_mri.astype(np.float32)

X_val_brain_ct = np.load('/kaggle/input/teacher-1-brain-mri-ctscan/X_val_ct.npy')
X_val_brain_ct = X_val_brain_ct.astype(np.float32)

images_train_brain_mri = np.load('/kaggle/input/teacher-1-brain-mri-ctscan/images_train (1).npy')
images_train_brain_mri = images_train_brain_mri.astype(np.float32)

images_train_brain_ct = np.load('/kaggle/input/teacher-1-brain-mri-ctscan/images_train_ct.npy')
images_train_brain_ct = images_train_brain_ct.astype(np.float32)

labels_train_brain_ct = np.load('/kaggle/input/teacher-1-brain-mri-ctscan/labels_train_ct.npy')
labels_train_brain_mri = np.load('/kaggle/input/teacher-1-brain-mri-ctscan/labels_train_mri.npy')

y_test_brain_ct = np.load('/kaggle/input/teacher-1-brain-mri-ctscan/y_test_ct.npy')
y_test_brain_mri = np.load('/kaggle/input/teacher-1-brain-mri-ctscan/y_test_mri.npy')
y_val_brain_mri = np.load('/kaggle/input/teacher-1-brain-mri-ctscan/y_val_mri.npy')
y_val_brain_ct = np.load('/kaggle/input/teacher-1-brain-mri-ctscan/y_val_ct.npy')

### Generated soft probabilities by teacher 1 model of MMF-MTL-TS approach

soft_prob_brain_mri = np.load('/kaggle/input/teacher-1-soft-predictions-brain/soft_pred_train_teacher1_brain_mri.npy')
soft_prob_brain_ct = np.load('/kaggle/input/teacher-1-soft-predictions-brain/soft_pred_train_teacher1_brain_ctscan.npy')

print('X_test_brain_mri:',X_test_brain_mri.shape)
print('X_test_brain_ct:',X_test_brain_ct.shape)
print('X_val_brain_mri:',X_val_brain_mri.shape)
print('X_val_brain_ct:',X_val_brain_ct.shape)

print('images_train_brain_mri:',images_train_brain_mri.shape)
print('images_train_brain_ct:',images_train_brain_ct.shape)
print('labels_train_brain_mri:',labels_train_brain_mri.shape)
print('labels_train_brain_ct:',labels_train_brain_ct.shape)

print('y_test_brain_mri:',y_test_brain_mri.shape)
print('y_test_brain_ct:',y_test_brain_ct.shape)
print('y_val_brain_mri:',y_val_brain_mri.shape)
print('y_val_brain_ct:',y_val_brain_ct.shape)

print('soft_prob_brain_mri:',soft_prob_brain_mri.shape)
print('soft_prob_brain_ct:',soft_prob_brain_ct.shape)
# Out:
# X_test_brain_mri: (656, 128, 128, 3)
# X_test_brain_ct: (656, 128, 128, 3)
# X_val_brain_mri: (655, 128, 128, 3)
# X_val_brain_ct: (655, 128, 128, 3)
# images_train_brain_mri: (5712, 128, 128, 3)
# images_train_brain_ct: (5712, 128, 128, 3)
# labels_train_brain_mri: (5712, 4)
# labels_train_brain_ct: (5712, 2)
# y_test_brain_mri: (656, 4)
# y_test_brain_ct: (656, 2)
# y_val_brain_mri: (655, 4)
# y_val_brain_ct: (655, 2)
# soft_prob_brain_mri: (5712, 4)
# soft_prob_brain_ct: (5712, 2)

# %% [markdown]
# ## Proposed Method: MMF-MTL-TS

# %% [markdown]
# ### GSCA layer

# %%
import tensorflow as tf
from tensorflow.keras import layers

class DeeperGlobalLocalAttentionLayer(layers.Layer):
    def __init__(self, units, activation='sigmoid', dropout_rate=0.2, use_scale=True, **kwargs):
        super(DeeperGlobalLocalAttentionLayer, self).__init__(**kwargs)
        self.units = units
        self.activation = activation
        self.dropout_rate = dropout_rate
        self.use_scale = use_scale

    def build(self, input_shape):
        _, _, _, channels = input_shape
        ## global attention
        self.global_avg_pooling = layers.GlobalAveragePooling2D()
        self.global_attention = layers.Dense(units=self.units, activation=self.activation)
        
        ## Spatial attention
        self.local_conv1 = layers.Conv2D(filters=self.units, kernel_size=(1, 1), activation=self.activation)
        self.local_conv2 = layers.Conv2D(filters=self.units, kernel_size=(1, 1), activation=self.activation)
        
        if self.use_scale:
            self.global_scale = self.add_weight(shape=(1, 1, 1, 1), initializer='ones', trainable=True, name='global_scale')
            self.local_scale = self.add_weight(shape=(1, 1, 1, self.units), initializer='ones', trainable=True, name='local_scale')
        
        super(DeeperGlobalLocalAttentionLayer, self).build(input_shape)

    def call(self, inputs, training=None):
        # Deeper Global Attention
        global_avg = self.global_avg_pooling(inputs)
        global_attention = self.global_attention(global_avg)
        global_attention = tf.expand_dims(tf.expand_dims(global_attention, 1), 1)

        # Deeper Spatial Attention
        local_attention1 = self.local_conv1(inputs)
        local_attention1 = tf.reduce_mean(local_attention1, axis=[1, 2], keepdims=True)  # Reduce spatial dimensions
        local_attention2 = self.local_conv2(local_attention1)
        local_attention = tf.reduce_mean(local_attention2, axis=[1, 2], keepdims=True)  # Reduce spatial dimensions

        # Scale Global and Spatial Attention
        if self.use_scale:
            global_attention *= self.global_scale
            local_attention *= self.local_scale

        # Combine Global and Spatial Attention
        attention = tf.sigmoid(global_attention + local_attention)
        return attention

    def get_config(self):
        config = super(DeeperGlobalLocalAttentionLayer, self).get_config()
        config.update({'units': self.units, 'activation': self.activation, 'dropout_rate': self.dropout_rate,
                       'use_scale': self.use_scale})
        return config

class DeeperAttentionLayer(layers.Layer):
    def __init__(self, units=64, use_scale=True, **kwargs):
        super(DeeperAttentionLayer, self).__init__(**kwargs)
        self.units = units
        self.use_scale = use_scale

    def build(self, input_shape):
        _, H, W, C = input_shape
        # add weights to the channel to perform channel-wise attention
        self.alpha = self.add_weight(shape=(1, 1, 1, C), initializer='ones', trainable=True, name='alpha')
        self.deeper_global_local_attention = DeeperGlobalLocalAttentionLayer(units=self.units, activation='sigmoid', 
                                                                              dropout_rate=0.2,  # You can adjust the dropout rate
                                                                              use_scale=self.use_scale)
        super(DeeperAttentionLayer, self).build(input_shape)

    def call(self, inputs, training=None):
        attention = self.deeper_global_local_attention(inputs, training=training)
        attention_feature = inputs * attention * self.alpha
        return attention_feature

    def get_config(self):
        config = super(DeeperAttentionLayer, self).get_config()
        config.update({'units': self.units, 'use_scale': self.use_scale})
        return config

# %%
def residual_GLC_branch(inputs):
    
    x = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2), padding='same')(inputs)
    x = DeeperAttentionLayer(units=64, use_scale=True)(x)
    
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)

    x = RGSA(x, filters=64)
    x = DeeperAttentionLayer(units=64, use_scale=True)(x)
    x = RGSA(x, filters=64)
    x = DeeperAttentionLayer(units=64, use_scale=True)(x)
    x = tf.keras.layers.Dropout(0.25)(x, training = True)

    x = RGSA(x, filters=128, strides=(2, 2), use_projection=True)
    x = DeeperAttentionLayer(units=128, use_scale=True)(x)
    x = RGSA(x, filters=128)
    x = DeeperAttentionLayer(units=128, use_scale=True)(x)
    x = tf.keras.layers.Dropout(0.25)(x, training = True)

    x = RGSA(x, filters=256, strides=(2, 2), use_projection=True)
    x = DeeperAttentionLayer(units=256, use_scale=True)(x)
    x = RGSA(x, filters=256)
    x = DeeperAttentionLayer(units=256, use_scale=True)(x)
    x = tf.keras.layers.Dropout(0.25)(x, training = True)

    x = RGSA(x, filters=512, strides=(2, 2), use_projection=True)
    x = DeeperAttentionLayer(units=512, use_scale=True)(x)
    
    x = RGSA(x, filters=512)
    x = DeeperAttentionLayer(units=512, use_scale=True)(x)
    
    return x

# %%
import tensorflow as tf
tf.keras.mixed_precision.set_global_policy('mixed_float16')

import tensorflow as tf
import numpy as np
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, ReLU, Add
from tensorflow.keras.models import Model
from tensorflow.keras.losses import KLDivergence
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications import DenseNet121, ResNet50V2
from tensorflow.keras.layers import GlobalAveragePooling2D
import copy
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, ReLU, Add
from tensorflow.keras.models import Model
from tensorflow.keras.losses import KLDivergence
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications import DenseNet169, MobileNetV2, ResNet50, EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D
import copy

# %% [markdown]
# ## AKD Loss

# %%
import tensorflow as tf
from tensorflow.keras.losses import KLDivergence, CategoricalCrossentropy

#@tf.keras.utils.register_keras_serializable()
def adaptive_knowledge_distillation_loss(y_true, y_pred, temperature=10, alpha=0.5, 
                                         beta=0.1, target_loss_weight=0.5):
    # Compute hard target loss
    hard_target_loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True)(y_true, y_pred)

    # Compute adaptive temperature
    adaptive_temperature = temperature * (1 + beta * hard_target_loss)

    # Soften the teacher and student predictions with adaptive temperature
    y_true_soft_adaptive = tf.nn.softmax(y_true / adaptive_temperature, axis=-1)
    y_pred_soft_adaptive = tf.nn.softmax(y_pred / adaptive_temperature, axis=-1)

    # Compute cross-entropy loss between softened predictions
    soft_target_loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(y_true_soft_adaptive, y_pred_soft_adaptive)

    # Compute KL divergence between softened predictions
    kl_divergence_loss = tf.keras.losses.KLDivergence()(y_true_soft_adaptive, y_pred_soft_adaptive)

    # Weighted sum of cross-entropy loss and KL divergence to develop soft loss
    loss = alpha * soft_target_loss + (1 - alpha) * kl_divergence_loss

    # Combine losses based on adaptive temperature to generate AKD loss based on soft and hard loss
    final_loss = (1 - target_loss_weight) * loss + target_loss_weight * hard_target_loss

    return final_loss

# %%
def RGSA(x, filters, strides=(1, 1), use_projection=False):
    shortcut = x

    # Define the first convolutional layer of the block
    
    x = Conv2D(filters=filters, kernel_size=(3, 3), strides=strides, padding='same', 
               #activation = 'relu'

              )(x)
    x = DeeperAttentionLayer(units=filters, use_scale=True)(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    # Define the second convolutional layer of the block
    
    x = Conv2D(filters=filters, kernel_size=(3, 3), padding='same')(x)
    x = DeeperAttentionLayer(units=filters, use_scale=True)(x)
    
    x = BatchNormalization()(x)

    # If the stride is not (1, 1), the dimensions need to be adjusted
    if strides != (1, 1) or use_projection:
        
        shortcut = Conv2D(filters=filters, kernel_size=(1, 1), strides=strides, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)

    # Add the shortcut (identity connection)
    
    x = tf.keras.layers.add([x, shortcut])
    
    x = tf.keras.layers.Activation('relu')(x)
    return x

#def build_resnet18(input_shape=(128, 128, 3), num_classes=2):
input_shape=(128, 128, 3)
inputs = Input(shape=input_shape)
inputs2 = Input(shape=input_shape)
inputs3 = Input(shape=input_shape)
inputs4 = Input(shape=input_shape)

#input_data = Input(shape=input_shape, name='input_data')
# Initial convolutional layer

x = residual_GLC_branch(inputs)
x2 = residual_GLC_branch(inputs2)
x3 = residual_GLC_branch(inputs3)
x4 = residual_GLC_branch(inputs4)

print('x:',x.shape)
print('x2:',x2.shape)
print('x3:',x3.shape)
print('x4:',x4.shape)
# Global average pooling and fully connected layer

con = tf.keras.layers.Concatenate(axis=-1)([x, x2])

x = GlobalAveragePooling2D()(con)

con2 = tf.keras.layers.Concatenate(axis=-1)([x3, x4])
x3 = GlobalAveragePooling2D()(con2)

outputs1 = Dense(4, activation='softmax')(x)
outputs2 = Dense(2, activation='sigmoid')(x)

outputs3 = Dense(3, activation='softmax')(x3)
outputs4 = Dense(2, activation='sigmoid')(x3)

# Create the model
student_model = Model([inputs, inputs2,inputs3, inputs4], [outputs1, outputs2, outputs3, outputs4])
#return model
print(student_model.summary())
# Instantiate the ResNet-18 model
#model = build_resnet18()


#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Train the model
#model.fit(images_train, y_train_one_hot, epochs=10, batch_size=32, validation_split=0.2)
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
def checkpoint_callback():

    checkpoint_filepath = 'best_student_models1_covid_brain.keras'

    model_checkpoint_callback= ModelCheckpoint(filepath=checkpoint_filepath,
                           save_weights_only=False,
                           #frequency='epoch',
                           monitor='val_loss',
                           save_best_only=True,
                           verbose=0)

    return model_checkpoint_callback

def early_stopping(patience):
    es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, verbose=1)
    return es_callback



checkpoint_callback = checkpoint_callback()
early_stopping = early_stopping(patience=100)
callbacks = [checkpoint_callback, early_stopping]
#model.summary()
'''def distillation_loss(y_true, y_pred):
    y_true = tf.dtypes.cast(y_true, tf.float32)
    y_true = tf.nn.softmax(y_true / temperature, axis=-1)
    y_pred = tf.nn.softmax(y_pred / temperature, axis=-1)
    return KLDivergence()(y_true, y_pred)
'''
'''adaptive_distillation_loss = AdaptiveKnowledgeDistillationLoss(temperature=10, 
                                                               alpha=0.5, beta=0.1, 
                                                               target_loss_weight=0.5)
'''
student_model.compile(optimizer='adam', loss=[adaptive_knowledge_distillation_loss,
                                              adaptive_knowledge_distillation_loss,
                                             adaptive_knowledge_distillation_loss,
                                             adaptive_knowledge_distillation_loss], 
                      metrics=['accuracy', 'accuracy', 'accuracy', 'accuracy'])

'''
print('X_test_covid_ct:',X_test_covid_ct.shape)
print('X_test_covid_cxr:',X_test_covid_cxr.shape)
print('X_val_covid_ct:',X_val_covid_ct.shape)
print('X_val_covid_cxr:',X_val_covid_cxr.shape)

print('images_train_covid_ct:',images_train_covid_ct.shape)
print('images_train_covid_cxr:',images_train_covid_cxr.shape)
print('labels_train_covid_ct:',labels_train_covid_ct.shape)
print('labels_train_covid_cxr:',labels_train_covid_cxr.shape)

print('y_test_covid_ct:',y_test_covid_ct.shape)
print('y_test_covid_cxr:',y_test_covid_cxr.shape)
print('y_val_covid_ct:',y_val_covid_ct.shape)
print('y_val_covid_cxr:',y_val_covid_cxr.shape)

print('soft_prob_covid_cxr:',soft_prob_covid_cxr.shape)
print('soft_prob_covid_ct:',soft_prob_covid_ct.shape)

print('X_test_brain_mri:',X_test_brain_mri.shape)
print('X_test_brain_ct:',X_test_brain_ct.shape)
print('X_val_brain_mri:',X_val_brain_mri.shape)
print('X_val_brain_ct:',X_val_brain_ct.shape)

print('images_train_brain_mri:',images_train_brain_mri.shape)
print('images_train_brain_ct:',images_train_brain_ct.shape)
print('labels_train_brain_mri:',labels_train_brain_mri.shape)
print('labels_train_brain_ct:',labels_train_brain_ct.shape)

print('y_test_brain_mri:',y_test_brain_mri.shape)
print('y_test_brain_ct:',y_test_brain_ct.shape)
print('y_val_brain_mri:',y_val_brain_mri.shape)
print('y_val_brain_ct:',y_val_brain_ct.shape)
#[X_val_covid_cxr, X_val_covid_ct], [y_val_covid_cxr, y_val_covid_ct]


print('soft_prob_brain_mri:',soft_prob_brain_mri.shape)
print('soft_prob_brain_ct:',soft_prob_brain_ct.shape)
'''
student_model.fit(
    x = [images_train_brain_mri, images_train_brain_ct, 
         images_train_covid_cxr,  images_train_covid_ct], 
    
    y=([soft_prob_brain_mri, soft_prob_brain_ct, soft_prob_covid_cxr, soft_prob_covid_ct]),
    epochs=200,
    #validation_data=([X_val, X_val_c], [y_val, y_val_c]), 
    callbacks = [callbacks],#batch_size=16,
    #validation_split = 0.2
    validation_data = ([X_val_brain_mri, X_val_brain_ct, X_val_covid_cxr, X_val_covid_ct],
                      [y_val_brain_mri, y_val_brain_ct, y_val_covid_cxr, y_val_covid_ct]), verbose=0
    
)
# Out:
# x: (None, 4, 4, 512)
# x2: (None, 4, 4, 512)
# x3: (None, 4, 4, 512)
# x4: (None, 4, 4, 512)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 64, 64,    │      9,472 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_70 (Conv2D)  │ (None, 64, 64,    │      9,472 │ input_layer_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_140 (Conv2D) │ (None, 64, 64,    │      9,472 │ input_layer_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_210 (Conv2D) │ (None, 64, 64,    │      9,472 │ input_layer_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 64, 64,    │     12,609 │ conv2d[0][0]      │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 64, 64,    │     12,609 │ conv2d_70[0][0]   │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 64, 64,    │     12,609 │ conv2d_140[0][0]  │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 64, 64,    │     12,609 │ conv2d_210[0][0]  │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 64,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 32, 32,    │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ activation_17[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ activation_34[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 32, 32,    │          0 │ activation_51[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │     36,928 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_73 (Conv2D)  │ (None, 32, 32,    │     36,928 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_143 (Conv2D) │ (None, 32, 32,    │     36,928 │ max_pooling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_213 (Conv2D) │ (None, 32, 32,    │     36,928 │ max_pooling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_3[0][0]    │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_73[0][0]   │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_143[0][0]  │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_213[0][0]  │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │     36,928 │ activation_1[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_76 (Conv2D)  │ (None, 32, 32,    │     36,928 │ activation_18[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_146 (Conv2D) │ (None, 32, 32,    │     36,928 │ activation_35[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_216 (Conv2D) │ (None, 32, 32,    │     36,928 │ activation_52[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_6[0][0]    │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_76[0][0]   │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_146[0][0]  │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_216[0][0]  │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 32, 32,    │          0 │ add[0][0]         │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 32, 32,    │          0 │ add_8[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 32, 32,    │          0 │ add_16[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, 32, 32,    │          0 │ add_24[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ activation_2[0][… │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ activation_19[0]… │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ activation_36[0]… │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ activation_53[0]… │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │     36,928 │ deeper_attention… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_81 (Conv2D)  │ (None, 32, 32,    │     36,928 │ deeper_attention… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_151 (Conv2D) │ (None, 32, 32,    │     36,928 │ deeper_attention… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_221 (Conv2D) │ (None, 32, 32,    │     36,928 │ deeper_attention… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_11[0][0]   │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_81[0][0]   │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_151[0][0]  │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_221[0][0]  │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 32, 32,    │     36,928 │ activation_3[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_84 (Conv2D)  │ (None, 32, 32,    │     36,928 │ activation_20[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_154 (Conv2D) │ (None, 32, 32,    │     36,928 │ activation_37[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_224 (Conv2D) │ (None, 32, 32,    │     36,928 │ activation_54[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_14[0][0]   │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_84[0][0]   │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_154[0][0]  │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ conv2d_224[0][0]  │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ deeper_attention… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ deeper_attention… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ deeper_attention… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ deeper_attention… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ deeper_attention… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 32, 32,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 32, 32,    │          0 │ add_9[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 32, 32,    │          0 │ add_17[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, 32, 32,    │          0 │ add_25[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ activation_4[0][… │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ activation_21[0]… │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ activation_38[0]… │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 32, 32,    │     12,609 │ activation_55[0]… │
# │ (DeeperAttentionLa… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 32, 32,    │          0 │ deeper_attention… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 32, 32,    │          0 │ deeper_attention… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 32, 32,    │          0 │ deeper_attention… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 32, 32,    │          0 │ deeper_attention… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 16, 16,    │     73,856 │ dropout[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_89 (Conv2D)  │ (None, 16, 16,    │     73,856 │ dropout_3[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_159 (Conv2D) │ (None, 16, 16,    │     73,856 │ dropout_6[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_229 (Conv2D) │ (None, 16, 16,    │     73,856 │ dropout_9[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_19[0][0]   │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_89[0][0]   │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_159[0][0]  │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_229[0][0]  │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 16, 16,    │    147,584 │ activation_5[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, 16, 16,    │    147,584 │ activation_22[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_162 (Conv2D) │ (None, 16, 16,    │    147,584 │ activation_39[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_232 (Conv2D) │ (None, 16, 16,    │    147,584 │ activation_56[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_22[0][0]   │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 16, 16,    │      8,320 │ dropout[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_92[0][0]   │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_95 (Conv2D)  │ (None, 16, 16,    │      8,320 │ dropout_3[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_162[0][0]  │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_165 (Conv2D) │ (None, 16, 16,    │      8,320 │ dropout_6[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_232[0][0]  │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_235 (Conv2D) │ (None, 16, 16,    │      8,320 │ dropout_9[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_95[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_165[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_235[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 16, 16,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 16, 16,    │          0 │ add_10[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 16, 16,    │          0 │ add_18[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (None, 16, 16,    │          0 │ add_26[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ activation_6[0][… │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ activation_23[0]… │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ activation_40[0]… │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ activation_57[0]… │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 16, 16,    │    147,584 │ deeper_attention… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_98 (Conv2D)  │ (None, 16, 16,    │    147,584 │ deeper_attention… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_168 (Conv2D) │ (None, 16, 16,    │    147,584 │ deeper_attention… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_238 (Conv2D) │ (None, 16, 16,    │    147,584 │ deeper_attention… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_28[0][0]   │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_98[0][0]   │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_168[0][0]  │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_238[0][0]  │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_58       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 16, 16,    │    147,584 │ activation_7[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_101 (Conv2D) │ (None, 16, 16,    │    147,584 │ activation_24[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_171 (Conv2D) │ (None, 16, 16,    │    147,584 │ activation_41[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_241 (Conv2D) │ (None, 16, 16,    │    147,584 │ activation_58[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_31[0][0]   │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_101[0][0]  │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_171[0][0]  │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ conv2d_241[0][0]  │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ deeper_attention… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ deeper_attention… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ deeper_attention… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ deeper_attention… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ deeper_attention… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 16, 16,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 16, 16,    │          0 │ add_11[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 16, 16,    │          0 │ add_19[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_59       │ (None, 16, 16,    │          0 │ add_27[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ activation_8[0][… │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ activation_25[0]… │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ activation_42[0]… │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 16, 16,    │     49,793 │ activation_59[0]… │
# │ (DeeperAttentionLa… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16, 16,    │          0 │ deeper_attention… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ deeper_attention… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 16, 16,    │          0 │ deeper_attention… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 16, 16,    │          0 │ deeper_attention… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 8, 8, 256) │    295,168 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_106 (Conv2D) │ (None, 8, 8, 256) │    295,168 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_176 (Conv2D) │ (None, 8, 8, 256) │    295,168 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_246 (Conv2D) │ (None, 8, 8, 256) │    295,168 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 8, 8, 256) │    197,889 │ conv2d_36[0][0]   │
# │ (DeeperAttentionLa… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 8, 8, 256) │    197,889 │ conv2d_106[0][0]  │
# │ (DeeperAttentionLa… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 8, 8, 256) │    197,889 │ conv2d_176[0][0]  │
# │ (DeeperAttentionLa… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deeper_attention_l… │ (None, 8, 8, 256) │    197,889 │ conv2d_246[0][0]  │
# ...
# W0000 00:00:1710342808.230930     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342808.260762     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342808.524795     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342808.554859     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342808.817535     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342808.845923     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342809.112876     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342809.141202     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342809.408819     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342809.436696     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342809.699532     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342809.726915     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342809.987067     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342810.014186     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342810.277025     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342810.306207     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342810.571146     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342810.601587     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342810.864754     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342810.893584     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342811.165450     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342811.194564     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342811.459697     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342811.489145     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342811.755697     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342811.787745     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342812.051607     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342812.080617     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342812.355606     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342812.385953     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342812.657443     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342812.687760     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342812.950388     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342812.978055     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342813.241790     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342813.269182     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342813.534111     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342813.563304     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342813.827887     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342813.856365     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342814.122728     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342814.152226     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342814.420802     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342814.450980     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342814.715832     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342814.743852     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342815.005734     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342815.034418     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342815.296158     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342815.325292     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342815.595484     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342815.627592     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342815.899948     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342815.931350     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342816.196425     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342816.226067     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342816.492385     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342816.526993     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342816.794036     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342816.824560     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342817.088538     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342817.116434     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342817.379149     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342817.407330     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342817.671590     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342817.699222     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342817.961227     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342817.989005     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342818.252744     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342818.280985     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342818.549200     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342818.579618     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342818.844336     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342818.873573     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342819.139213     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342819.167856     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342819.432924     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342819.464174     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342819.733358     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342819.763205     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342820.022604     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342820.050322     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342820.311190     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342820.339486     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342820.602075     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342820.631971     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342820.892599     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342820.920669     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342821.170717     111 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342821.233284     111 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342822.862005     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342822.920863     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342823.161714     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342823.179256     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342823.413783     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342823.432704     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342823.666369     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342823.684307     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342823.917477     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342823.935712     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342824.171785     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342824.189504     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342824.423720     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342824.441462     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342824.673124     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342824.690293     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342824.925154     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342824.943098     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342825.176737     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342825.193944     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342825.426944     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342825.444909     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342825.678600     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342825.695834     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342825.932088     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342825.950725     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.
# W0000 00:00:1710342826.185010     113 graph_launch.cc:161] Evict all gpu graphs from executor 0x5b1bcfa6a180
# W0000 00:00:1710342826.202304     113 graph_launch.cc:363] InstantiateAllGraph failed due to insufficient memory. Uninitializd graphs will run in op-by-op mode.

# %%
student_model.evaluate([X_test_brain_mri, X_test_brain_ct,X_test_covid_cxr, X_test_covid_ct], 
[y_test_brain_mri,y_test_brain_ct, y_test_covid_cxr, y_test_covid_ct])
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 18s 908ms/step - dense_100_accuracy: 0.9921 - dense_101_accuracy: 0.9882 - dense_102_accuracy: 0.9509 - dense_103_accuracy: 0.9537 - loss: 1.9846
# [1.9803009033203125,
#  0.9847561120986938,
#  0.9817073345184326,
#  0.9603658318519592,
#  0.9679877758026123]

# %%
student_model.save('best_student_brain_covid_diseases_1.keras')

# %%
y_pred = student_model.predict([X_test_brain_mri, X_test_brain_ct,X_test_covid_cxr, X_test_covid_ct]) 
#[y_test_brain_mri,y_test_brain_ct, y_test_covid_cxr, y_test_covid_ct])
#[X_test_mri, X_test_ct], [y_test_mri, y_test_ct]
y_pred_binary1 = y_pred[0] >= 0.5
y_pred_binary_pgd_test1 = np.array(y_pred_binary1, dtype='int32')

print('y_pred_binary_pgd_test1:', y_pred_binary_pgd_test1.shape)

y_pred_binary2 = y_pred[1] >= 0.5
y_pred_binary_pgd_test2 = np.array(y_pred_binary2, dtype='int32')

print('y_pred_binary_pgd_test2:', y_pred_binary_pgd_test2.shape)

y_pred_binary3 = y_pred[2] >= 0.5
y_pred_binary_pgd_test3 = np.array(y_pred_binary3, dtype='int32')

print('y_pred_binary_pgd_test3:', y_pred_binary_pgd_test3.shape)

y_pred_binary4 = y_pred[3] >= 0.5
y_pred_binary_pgd_test4 = np.array(y_pred_binary4, dtype='int32')

print('y_pred_binary_pgd_test4:', y_pred_binary_pgd_test4.shape)

# Calculate evaluation metrics for the current epsilon
y_test_categorical1 = y_test_brain_mri
y_test_categorical2 = y_test_brain_ct
y_test_categorical4 = y_test_covid_ct
y_test_categorical3 = y_test_covid_cxr

## Task 1:
print('Brain Tumours classification in MRI images:')
accuracy = accuracy_score(y_pred_binary_pgd_test1, y_test_categorical1) * 100
precision = precision_score(y_pred_binary_pgd_test1, y_test_categorical1, average='macro') * 100
recall = recall_score(y_pred_binary_pgd_test1, y_test_categorical1, average='macro') * 100
f1 = f1_score(y_pred_binary_pgd_test1, y_test_categorical1, average='macro') * 100
#auc = roc_auc_score(y_pred, y_train_categorical, multi_class='ovr') * 100
print('accuracy:', accuracy)
print('precision:', precision)
print('recall:', recall)
print('f1:', f1)

## Task 2:
print('Brain Stroke classification in CT scan images:')
accuracy = accuracy_score(y_pred_binary_pgd_test2, y_test_categorical2) * 100
precision = precision_score(y_pred_binary_pgd_test2, y_test_categorical2, average='macro') * 100
recall = recall_score(y_pred_binary_pgd_test2, y_test_categorical2, average='macro') * 100
f1 = f1_score(y_pred_binary_pgd_test2, y_test_categorical2, average='macro') * 100
print('accuracy:', accuracy)
print('precision:', precision)
print('recall:', recall)
print('f1:', f1)

## Task 3:
print('COVID19 classification in CXR images:')
accuracy = accuracy_score(y_pred_binary_pgd_test3, y_test_categorical3) * 100
precision = precision_score(y_pred_binary_pgd_test3, y_test_categorical3, average='macro') * 100
recall = recall_score(y_pred_binary_pgd_test3, y_test_categorical3, average='macro') * 100
f1 = f1_score(y_pred_binary_pgd_test3, y_test_categorical3, average='macro') * 100
#auc = roc_auc_score(y_pred, y_train_categorical, multi_class='ovr') * 100
print('accuracy:', accuracy)
print('precision:', precision)
print('recall:', recall)
print('f1:', f1)

## Task 2:
print('COVID19 classification in CT scan images:')
accuracy = accuracy_score(y_pred_binary_pgd_test4, y_test_categorical4) * 100
precision = precision_score(y_pred_binary_pgd_test4, y_test_categorical4, average='macro') * 100
recall = recall_score(y_pred_binary_pgd_test4, y_test_categorical4, average='macro') * 100
f1 = f1_score(y_pred_binary_pgd_test4, y_test_categorical4, average='macro') * 100
print('accuracy:', accuracy)
print('precision:', precision)
print('recall:', recall)
print('f1:', f1)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step
# y_pred_binary_pgd_test1: (656, 4)
# y_pred_binary_pgd_test2: (656, 2)
# y_pred_binary_pgd_test3: (656, 3)
# y_pred_binary_pgd_test4: (656, 2)
# Brain Tumours classification in MRI images:
# accuracy: 98.47560975609755
# precision: 98.46248586658052
# recall: 98.47261291340239
# f1: 98.44186689599287
# Brain Stroke classification in CT scan images:
# accuracy: 98.17073170731707
# precision: 98.13409234661606
# recall: 97.98423645320197
# f1: 98.05807998579084
# COVID19 classification in CXR images:
# accuracy: 96.03658536585365
# precision: 96.2687766555234
# recall: 96.09741626683575
# f1: 96.17757646386244
# COVID19 classification in CT scan images:
# accuracy: 96.79878048780488
# precision: 96.81458269214627
# recall: 96.76878354203934
# f1: 96.78964184092227

# %%
model1 = load_model('/kaggle/working/best_student_models1_covid_brain.keras', 
                    custom_objects={'DeeperAttentionLayer':DeeperAttentionLayer,
                                   #'adaptive_knowledge_distillation_loss1':adaptive_knowledge_distillation_loss1,
                                   'adaptive_knowledge_distillation_loss':adaptive_knowledge_distillation_loss})
#[X_test_covid_cxr, X_test_covid_ct], [y_test_covid_cxr, y_test_covid_ct]
# Now you can use the loaded model for evaluation or further training
model1.evaluate([X_test_brain_mri, X_test_brain_ct,X_test_covid_cxr, X_test_covid_ct], 
[y_test_brain_mri,y_test_brain_ct, y_test_covid_cxr, y_test_covid_ct])
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 47s 831ms/step - dense_100_accuracy: 0.9826 - dense_101_accuracy: 0.9912 - dense_102_accuracy: 0.9626 - dense_103_accuracy: 0.9738 - loss: 1.9718
# [1.9717508554458618,
#  0.9817073345184326,
#  0.9893292784690857,
#  0.9664633870124817,
#  0.9740853905677795]

# %%
y_pred = model1.predict([X_test_brain_mri, X_test_brain_ct,X_test_covid_cxr, X_test_covid_ct],
                       batch_size=32) 
#[y_test_brain_mri,y_test_brain_ct, y_test_covid_cxr, y_test_covid_ct])
#[X_test_mri, X_test_ct], [y_test_mri, y_test_ct]
y_pred_binary1 = y_pred[0] >= 0.5
y_pred_binary_pgd_test1 = np.array(y_pred_binary1, dtype='int32')

print('y_pred_binary_pgd_test1:', y_pred_binary_pgd_test1.shape)

y_pred_binary2 = y_pred[1] >= 0.5
y_pred_binary_pgd_test2 = np.array(y_pred_binary2, dtype='int32')

print('y_pred_binary_pgd_test2:', y_pred_binary_pgd_test2.shape)

y_pred_binary3 = y_pred[2] >= 0.5
y_pred_binary_pgd_test3 = np.array(y_pred_binary3, dtype='int32')

print('y_pred_binary_pgd_test3:', y_pred_binary_pgd_test3.shape)

y_pred_binary4 = y_pred[3] >= 0.5
y_pred_binary_pgd_test4 = np.array(y_pred_binary4, dtype='int32')

print('y_pred_binary_pgd_test4:', y_pred_binary_pgd_test4.shape)

# Calculate evaluation metrics for the current epsilon
y_test_categorical1 = y_test_brain_mri
y_test_categorical2 = y_test_brain_ct
y_test_categorical4 = y_test_covid_ct
y_test_categorical3 = y_test_covid_cxr

## Task 1:
print('Brain Tumours classification in MRI images:')
accuracy = accuracy_score(y_pred_binary_pgd_test1, y_test_categorical1) * 100
precision = precision_score(y_pred_binary_pgd_test1, y_test_categorical1, average='macro') * 100
recall = recall_score(y_pred_binary_pgd_test1, y_test_categorical1, average='macro') * 100
f1 = f1_score(y_pred_binary_pgd_test1, y_test_categorical1, average='macro') * 100
#auc = roc_auc_score(y_pred, y_train_categorical, multi_class='ovr') * 100
print('accuracy:', accuracy)
print('precision:', precision)
print('recall:', recall)
print('f1:', f1)

## Task 2:
print('Brain Stroke classification in CT scan images:')
accuracy = accuracy_score(y_pred_binary_pgd_test2, y_test_categorical2) * 100
precision = precision_score(y_pred_binary_pgd_test2, y_test_categorical2, average='macro') * 100
recall = recall_score(y_pred_binary_pgd_test2, y_test_categorical2, average='macro') * 100
f1 = f1_score(y_pred_binary_pgd_test2, y_test_categorical2, average='macro') * 100
print('accuracy:', accuracy)
print('precision:', precision)
print('recall:', recall)
print('f1:', f1)

## Task 3:
print('COVID19 classification in CXR images:')
accuracy = accuracy_score(y_pred_binary_pgd_test3, y_test_categorical3) * 100
precision = precision_score(y_pred_binary_pgd_test3, y_test_categorical3, average='macro') * 100
recall = recall_score(y_pred_binary_pgd_test3, y_test_categorical3, average='macro') * 100
f1 = f1_score(y_pred_binary_pgd_test3, y_test_categorical3, average='macro') * 100
#auc = roc_auc_score(y_pred, y_train_categorical, multi_class='ovr') * 100
print('accuracy:', accuracy)
print('precision:', precision)
print('recall:', recall)
print('f1:', f1)

## Task 2:
print('COVID19 classification in CT scan images:')
accuracy = accuracy_score(y_pred_binary_pgd_test4, y_test_categorical4) * 100
precision = precision_score(y_pred_binary_pgd_test4, y_test_categorical4, average='macro') * 100
recall = recall_score(y_pred_binary_pgd_test4, y_test_categorical4, average='macro') * 100
f1 = f1_score(y_pred_binary_pgd_test4, y_test_categorical4, average='macro') * 100
print('accuracy:', accuracy)
print('precision:', precision)
print('recall:', recall)
print('f1:', f1)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step
# y_pred_binary_pgd_test1: (656, 4)
# y_pred_binary_pgd_test2: (656, 2)
# y_pred_binary_pgd_test3: (656, 3)
# y_pred_binary_pgd_test4: (656, 2)
# Brain Tumours classification in MRI images:
# accuracy: 98.17073170731707
# precision: 98.1291377177739
# recall: 98.18835798809864
# f1: 98.14721364807681
# Brain Stroke classification in CT scan images:
# accuracy: 98.78048780487805
# precision: 98.54522454142948
# recall: 99.4673138115761
# f1: 99.0029427901641
# COVID19 classification in CXR images:
# accuracy: 96.64634146341463
# precision: 96.87642498860009
# recall: 96.64772276227386
# f1: 96.71197647941834
# COVID19 classification in CT scan images:
# accuracy: 97.40853658536585
# precision: 97.28463109594023
# recall: 97.57882882882882
# f1: 97.39277823886286
